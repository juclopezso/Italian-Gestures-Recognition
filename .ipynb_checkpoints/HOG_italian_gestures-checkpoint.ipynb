# %%
import numpy as np # linear algebra
import json
from matplotlib import pyplot as plt
from skimage import color
from skimage.feature import hog
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score
import cv2
from skimage import transform
from skimage.color import rgb2gray #To gray the frames
import pickle
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
datagen = ImageDataGenerator(
        rotation_range=24,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.05,
        horizontal_flip=True,
        fill_mode='nearest') #the strategy used for filling in newly created pixels

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory



for i in range(2,6):
    folder = str(i)
    for j in range(1,46):
        if j<10:
            image_route = "data/train/"+folder+"/archivo0000%d.png" %j
        else:
            image_route = "data/train/"+folder+"/archivo000%d.png" %j
        
        print(image_route)
        
        img = load_img(image_route)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)
            
        k = 0
        for batch in datagen.flow(x, batch_size=1, save_to_dir="preview/train/"+folder, save_prefix='archivo', save_format='png'):
            k += 1
            if k > 20:
                break  # otherwise the generator would loop indefinitely
# Out:
# data/train/2/archivo00001.png
# data/train/2/archivo00002.png
# data/train/2/archivo00003.png
# data/train/2/archivo00004.png
# data/train/2/archivo00005.png
# data/train/2/archivo00006.png
# data/train/2/archivo00007.png
# data/train/2/archivo00008.png
# data/train/2/archivo00009.png
# data/train/2/archivo00010.png
# data/train/2/archivo00011.png
# data/train/2/archivo00012.png
# data/train/2/archivo00013.png
# data/train/2/archivo00014.png
# data/train/2/archivo00015.png
# data/train/2/archivo00016.png
# data/train/2/archivo00017.png
# data/train/2/archivo00018.png
# data/train/2/archivo00019.png
# data/train/2/archivo00020.png
# data/train/2/archivo00021.png
# data/train/2/archivo00022.png
# data/train/2/archivo00023.png
# data/train/2/archivo00024.png
# data/train/2/archivo00025.png
# data/train/2/archivo00026.png
# data/train/2/archivo00027.png
# data/train/2/archivo00028.png
# data/train/2/archivo00029.png
# data/train/2/archivo00030.png
# data/train/2/archivo00031.png
# data/train/2/archivo00032.png
# data/train/2/archivo00033.png
# data/train/2/archivo00034.png
# data/train/2/archivo00035.png
# data/train/2/archivo00036.png
# data/train/2/archivo00037.png
# data/train/2/archivo00038.png
# data/train/2/archivo00039.png
# data/train/2/archivo00040.png
# data/train/2/archivo00041.png
# data/train/2/archivo00042.png
# data/train/2/archivo00043.png
# data/train/2/archivo00044.png
# data/train/2/archivo00045.png
# data/train/3/archivo00001.png
# data/train/3/archivo00002.png
# data/train/3/archivo00003.png
# data/train/3/archivo00004.png
# data/train/3/archivo00005.png
# data/train/3/archivo00006.png
# data/train/3/archivo00007.png
# data/train/3/archivo00008.png
# data/train/3/archivo00009.png
# data/train/3/archivo00010.png
# data/train/3/archivo00011.png
# data/train/3/archivo00012.png
# data/train/3/archivo00013.png
# data/train/3/archivo00014.png
# data/train/3/archivo00015.png
# data/train/3/archivo00016.png
# data/train/3/archivo00017.png
# data/train/3/archivo00018.png
# data/train/3/archivo00019.png
# data/train/3/archivo00020.png
# data/train/3/archivo00021.png
# data/train/3/archivo00022.png
# data/train/3/archivo00023.png
# data/train/3/archivo00024.png
# data/train/3/archivo00025.png
# data/train/3/archivo00026.png
# data/train/3/archivo00027.png
# data/train/3/archivo00028.png
# data/train/3/archivo00029.png
# data/train/3/archivo00030.png
# data/train/3/archivo00031.png
# data/train/3/archivo00032.png
# data/train/3/archivo00033.png
# data/train/3/archivo00034.png
# data/train/3/archivo00035.png
# data/train/3/archivo00036.png
# data/train/3/archivo00037.png
# data/train/3/archivo00038.png
# data/train/3/archivo00039.png
# data/train/3/archivo00040.png
# data/train/3/archivo00041.png
# data/train/3/archivo00042.png
# data/train/3/archivo00043.png
# data/train/3/archivo00044.png
# data/train/3/archivo00045.png
# data/train/4/archivo00001.png
# data/train/4/archivo00002.png
# data/train/4/archivo00003.png
# data/train/4/archivo00004.png
# data/train/4/archivo00005.png
# data/train/4/archivo00006.png
# data/train/4/archivo00007.png
# data/train/4/archivo00008.png
# data/train/4/archivo00009.png
# data/train/4/archivo00010.png
# data/train/4/archivo00011.png
# data/train/4/archivo00012.png
# data/train/4/archivo00013.png
# data/train/4/archivo00014.png
# data/train/4/archivo00015.png
# data/train/4/archivo00016.png
# data/train/4/archivo00017.png
# data/train/4/archivo00018.png
# data/train/4/archivo00019.png
# data/train/4/archivo00020.png
# data/train/4/archivo00021.png
# data/train/4/archivo00022.png
# data/train/4/archivo00023.png
# data/train/4/archivo00024.png
# data/train/4/archivo00025.png
# data/train/4/archivo00026.png
# data/train/4/archivo00027.png
# data/train/4/archivo00028.png
# data/train/4/archivo00029.png
# data/train/4/archivo00030.png
# data/train/4/archivo00031.png
# data/train/4/archivo00032.png
# data/train/4/archivo00033.png
# data/train/4/archivo00034.png
# data/train/4/archivo00035.png
# data/train/4/archivo00036.png
# data/train/4/archivo00037.png
# data/train/4/archivo00038.png
# data/train/4/archivo00039.png
# data/train/4/archivo00040.png
# data/train/4/archivo00041.png
# data/train/4/archivo00042.png
# data/train/4/archivo00043.png
# data/train/4/archivo00044.png
# data/train/4/archivo00045.png
# data/train/5/archivo00001.png
# data/train/5/archivo00002.png
# data/train/5/archivo00003.png
# data/train/5/archivo00004.png
# data/train/5/archivo00005.png
# data/train/5/archivo00006.png
# data/train/5/archivo00007.png
# data/train/5/archivo00008.png
# data/train/5/archivo00009.png
# data/train/5/archivo00010.png
# data/train/5/archivo00011.png
# data/train/5/archivo00012.png
# data/train/5/archivo00013.png
# data/train/5/archivo00014.png
# data/train/5/archivo00015.png
# data/train/5/archivo00016.png
# data/train/5/archivo00017.png
# data/train/5/archivo00018.png
# data/train/5/archivo00019.png
# data/train/5/archivo00020.png
# data/train/5/archivo00021.png
# data/train/5/archivo00022.png
# data/train/5/archivo00023.png
# data/train/5/archivo00024.png
# data/train/5/archivo00025.png
# data/train/5/archivo00026.png
# data/train/5/archivo00027.png
# data/train/5/archivo00028.png
# data/train/5/archivo00029.png
# data/train/5/archivo00030.png
# data/train/5/archivo00031.png
# data/train/5/archivo00032.png
# data/train/5/archivo00033.png
# data/train/5/archivo00034.png
# data/train/5/archivo00035.png
# data/train/5/archivo00036.png
# data/train/5/archivo00037.png
# data/train/5/archivo00038.png
# data/train/5/archivo00039.png
# data/train/5/archivo00040.png
# data/train/5/archivo00041.png
# data/train/5/archivo00042.png
# data/train/5/archivo00043.png
# data/train/5/archivo00044.png
# data/train/5/archivo00045.png

# %%
def hog_features(image_uri):
    ppc = 14

    image = cv2.imread(image_uri)
    image = cv2.resize(image, (180,180))
    image = rgb2gray(image)

    fd,hog_image = hog(image, orientations=8, pixels_per_cell=(ppc,ppc),
                       cells_per_block=(4, 4),block_norm='L2',visualise=True)

    return fd, hog_image

# %%
#train_data = {}
train_features = []
train_images = []
train_labels = []

train_size = 895
classes = 5

for i in range(1,classes+1):
    folder = str(i)
    
    #train_data[i] = []
    for j in range(1,train_size+1):
        if j<10:
            image_route = "preview/train/"+folder+"/archivo0000%d.png" %j
        elif j<100:
            image_route = "preview/train/"+folder+"/archivo000%d.png" %j
        elif j<1000:
            image_route = "preview/train/"+folder+"/archivo00%d.png" %j
        else:
            image_route = "preview/train/"+folder+"/archivo0%d.png" %j
            
        #print(image_route)
        h_f, h_i = hog_features(image_route)
            
        train_features.append(h_f)
        train_images.append(h_i)
        train_labels.append(i)
        #train_data[i].append([h_f, h_i])
# Out:
# /Users/juancho/anaconda3/envs/isproject/lib/python3.6/site-packages/skimage/feature/_hog.py:248: skimage_deprecation: Argument `visualise` is deprecated and will be changed to `visualize` in v0.16
#   'be changed to `visualize` in v0.16', skimage_deprecation)

# %%
validation_features = []
validation_images = []
validation_labels = []
images = []

for i in range(1,6):
    folder = str(i)
    #train_data[i] = []
    for j in range(1,7):
        if j<10:
            h_f, h_i = hog_features("data/validation/"+folder+"/archivo0000%d.png" %j)
        else:
            h_f, h_i = hog_features("data/validation/"+folder+"/archivo000%d.png" %j)
            
        images.append(cv2.imread("data/validation/"+folder+"/archivo0000%d.png" %j))
        validation_features.append(h_f)
        validation_images.append(h_i)
        validation_labels.append(i)
        #train_data[i].append([h_f, h_i])

# %%
#f = open("train_data.pkl","wb")
#pickle.dump(train_data,f)
#f.close()

# %%
plt.imshow(train_images[66])
print(train_labels[66], train_features[1]) #Features[][][0] Images[][][1]
# Out:
# 1 [0.003087   0.0006197  0.00154805 ... 0.0099645  0.01194751 0.19340517]

# %%
clf = svm.SVC()

#hog_features = np.array(hog_features)
#data_frame = np.hstack((hog_features,labels))
#np.random.shuffle(data_frame)

x_train, x_test = train_features[:], validation_features[:]
y_train, y_test = train_labels[:] , validation_labels[:]

clf.fit(x_train,y_train)
# Out:
# /Users/juancho/anaconda3/envs/isproject/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = clf.predict(x_test)

print("Accuracy: "+ str(accuracy_score(y_test, y_pred)))
print('\n')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.3
#
#
#               precision    recall  f1-score   support
#
#            1       0.15      0.33      0.21         6
#            2       0.33      0.17      0.22         6
#            3       0.33      0.33      0.33         6
#            4       0.33      0.17      0.22         6
#            5       0.60      0.50      0.55         6
#
#    micro avg       0.30      0.30      0.30        30
#    macro avg       0.35      0.30      0.31        30
# weighted avg       0.35      0.30      0.31        30

# %%
index = 2

print(clf.predict(validation_features[index].reshape(1, -1)))
plt.imshow(images[index])
# Out:
# [3]
